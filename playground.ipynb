# %%
from client_example import play_game

# %%
server_url = "http://localhost:8000"
start_prompt = "the most adorable dog"
play_game(server_url, start_prompt, n_rounds=3)
# Out:
# Round 1:
# Prompt: The image shows a fluffy, small dog with light brown and white fur, sitting and looking directly at the camera with a playful expression.
# Round 2:
# Prompt: The image shows a cute, fluffy puppy with a mix of white and brown fur, sitting against a white background. The puppy appears to be smiling, giving it a cheerful and adorable expression.
# Round 3:
# Prompt: The main idea of the image is a cute puppy with a mix of white, brown, and black fur, sitting on a white background with its mouth open, appearing happy and playful.
